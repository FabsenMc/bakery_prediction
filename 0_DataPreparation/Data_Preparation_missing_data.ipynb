# %%
# import csv-files

import pandas as pd

pfad_1 = 'validation_data.csv'
pfad_2 = 'train_data.csv'

# Einlesen der CSVs
daten_1 = pd.read_csv(pfad_1, usecols=['Datum', 'KielerWoche', 'Warengruppe', 'Umsatz', 'Bewoelkung', 'Temperatur', 'Windgeschwindigkeit', 'Wettercode', 'Beschreibung', 'FerienSH', 'Feiertag', 'Uhrzeit', 'Heim_Auswärts', 'Umschlag', 'Weihnachtsmarkt', 'Regen', 'Wochentag_MDMDFSS', 'Wochenende', 'Jahreszeit_FSHW', 'Temperatur_Kategorie'])
daten_2 = pd.read_csv(pfad_2, usecols=['Datum', 'KielerWoche', 'Warengruppe', 'Umsatz', 'Bewoelkung', 'Temperatur', 'Windgeschwindigkeit', 'Wettercode', 'Beschreibung', 'FerienSH', 'Feiertag', 'Uhrzeit', 'Heim_Auswärts', 'Umschlag', 'Weihnachtsmarkt', 'Regen', 'Wochentag_MDMDFSS', 'Wochenende', 'Jahreszeit_FSHW', 'Temperatur_Kategorie'])

daten_1['KielerWoche'] = daten_1['KielerWoche'].fillna(0.0)
daten_1['KielerWoche'] = daten_1['KielerWoche'].astype('int64')
daten_1['Warengruppe'] = daten_1['Warengruppe'].fillna(0.0)
daten_1['Warengruppe'] = daten_1['Warengruppe'].astype('int64')
daten_1['Umsatz'] = daten_1['Umsatz'].fillna(0.0)
daten_1['Bewoelkung'] = daten_1['Bewoelkung'].fillna(0.0)
daten_1['Bewoelkung'] = daten_1['Bewoelkung'].astype('int64')
daten_1['Temperatur'] = daten_1['Temperatur'].fillna(0.0)
daten_1['Windgeschwindigkeit'] = daten_1['Windgeschwindigkeit'].fillna(0.0)
daten_1['Windgeschwindigkeit'] = daten_1['Windgeschwindigkeit'].astype('int64')
daten_1['Wettercode'] = daten_1['Wettercode'].fillna(0.0)
daten_1['Wettercode'] = daten_1['Wettercode'].astype('int64')
daten_1['FerienSH'] = daten_1['FerienSH'].fillna(0.0)
daten_1['FerienSH'] = daten_1['FerienSH'].astype('int64')
daten_1['Feiertag'] = daten_1['Feiertag'].fillna(0.0)
daten_1['Feiertag'] = daten_1['Feiertag'].astype('int64')
daten_1['Uhrzeit'] = daten_1['Uhrzeit'].fillna('')
daten_1['Heim_Auswärts'] = daten_1['Heim_Auswärts'].fillna('')
daten_1['Umschlag'] = daten_1['Umschlag'].fillna(0.0)
daten_1['Umschlag'] = daten_1['Umschlag'].astype('int64')
daten_1['Weihnachtsmarkt'] = daten_1['Weihnachtsmarkt'].fillna(0.0)
daten_1['Weihnachtsmarkt'] = daten_1['Weihnachtsmarkt'].astype('int64')
daten_1['Regen'] = daten_1['Regen'].fillna(0.0)
daten_1['Regen'] = daten_1['Regen'].astype('int64')
daten_1['Wochentag_MDMDFSS'] = daten_1['Wochentag_MDMDFSS'].fillna(0.0)
daten_1['Wochentag_MDMDFSS'] = daten_1['Wochentag_MDMDFSS'].astype('int64')
daten_1['Wochenende'] = daten_1['Wochenende'].fillna(0.0)
daten_1['Wochenende'] = daten_1['Wochenende'].astype('int64')
daten_1['Jahreszeit_FSHW'] = daten_1['Jahreszeit_FSHW'].fillna(0.0)
daten_1['Jahreszeit_FSHW'] = daten_1['Jahreszeit_FSHW'].astype('int64')
daten_1['Temperatur_Kategorie'] = daten_1['Temperatur_Kategorie'].fillna(0.0)

daten_2['KielerWoche'] = daten_2['KielerWoche'].fillna(0.0)
daten_2['KielerWoche'] = daten_2['KielerWoche'].astype('int64')
daten_2['Warengruppe'] = daten_2['Warengruppe'].fillna(0.0)
daten_2['Warengruppe'] = daten_2['Warengruppe'].astype('int64')
daten_2['Umsatz'] = daten_2['Umsatz'].fillna(0.0)
daten_2['Bewoelkung'] = daten_2['Bewoelkung'].fillna(0.0)
daten_2['Bewoelkung'] = daten_2['Bewoelkung'].astype('int64')
daten_2['Temperatur'] = daten_2['Temperatur'].fillna(0.0)
daten_2['Windgeschwindigkeit'] = daten_2['Windgeschwindigkeit'].fillna(0.0)
daten_2['Windgeschwindigkeit'] = daten_2['Windgeschwindigkeit'].astype('int64')
daten_2['Wettercode'] = daten_2['Wettercode'].fillna(0.0)
daten_2['Wettercode'] = daten_2['Wettercode'].astype('int64')
daten_2['FerienSH'] = daten_2['FerienSH'].fillna(0.0)
daten_2['FerienSH'] = daten_2['FerienSH'].astype('int64')
daten_2['Feiertag'] = daten_2['Feiertag'].fillna(0.0)
daten_2['Feiertag'] = daten_2['Feiertag'].astype('int64')
daten_2['Uhrzeit'] = daten_2['Uhrzeit'].fillna('')
daten_2['Heim_Auswärts'] = daten_2['Heim_Auswärts'].fillna('')
daten_2['Umschlag'] = daten_2['Umschlag'].fillna(0.0)
daten_2['Umschlag'] = daten_2['Umschlag'].astype('int64')
daten_2['Weihnachtsmarkt'] = daten_2['Weihnachtsmarkt'].fillna(0.0)
daten_2['Weihnachtsmarkt'] = daten_2['Weihnachtsmarkt'].astype('int64')
daten_2['Regen'] = daten_2['Regen'].fillna(0.0)
daten_2['Regen'] = daten_2['Regen'].astype('int64')
daten_2['Wochentag_MDMDFSS'] = daten_2['Wochentag_MDMDFSS'].fillna(0.0)
daten_2['Wochentag_MDMDFSS'] = daten_2['Wochentag_MDMDFSS'].astype('int64')
daten_2['Wochenende'] = daten_2['Wochenende'].fillna(0.0)
daten_2['Wochenende'] = daten_2['Wochenende'].astype('int64')
daten_2['Jahreszeit_FSHW'] = daten_2['Jahreszeit_FSHW'].fillna(0.0)
daten_2['Jahreszeit_FSHW'] = daten_2['Jahreszeit_FSHW'].astype('int64')
daten_2['Temperatur_Kategorie'] = daten_2['Temperatur_Kategorie'].fillna(0.0)

daten_1.to_csv ('train_data_no_missing_data.csv', index=False)
daten_2.to_csv('validation_data_no_missing_data.csv', index=False)
